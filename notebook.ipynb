# %%
import json
import matplotlib.pyplot as plt
import os
import numpy as np
dump_path = 'test_data'
with open(os.path.join(dump_path, 'mnist_4_input.json'), 'r') as f:
    dump_raw = json.load(f)

# %%
dump_raw['shape']
# Out:
# [1, 28, 28, 1]

# %%
dump_array = np.array(dump_raw['data']).reshape((dump_raw['shape'][1], dump_raw['shape'][2]))
plt.imshow(dump_array)
