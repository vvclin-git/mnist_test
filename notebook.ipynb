# %%
import json
import matplotlib.pyplot as plt
import os
import numpy as np
import tensorflow as tf
# Out:
# WARNING:tensorflow:From d:\Coding Stuff\Python\mnist_test\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
dump_path = 'test_data'
with open(os.path.join(dump_path, 'mnist_6_input.json'), 'r') as f:
    dump_raw = json.load(f)

# %%
dump_array = np.array(dump_raw['data']).reshape((dump_raw['shape'][1], dump_raw['shape'][2]))
plt.imshow(dump_array)
plt.colorbar()
