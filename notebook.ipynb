# %%
import tensorflowjs as tfjs

tfjs.converters.convert_tf_saved_model(
    "mnist_saved_model",
    "web_model"
)
# Out:
# Running cells with 'mnist-test (Python 3.11.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"d:/Coding Stuff/Python/mnist_test/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'
